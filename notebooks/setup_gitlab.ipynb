# %% [markdown]
# ### Generate public Key for First *Time*
# #### First Step: Generate Key
# Notice: Please save key.zip somewhere on your local machine and once you should use gitlab you should manually upload to colab server by using left window named "Files"

# %%
#insert your email address.Enter file in which to save the key : use default path
# !ssh-keygen -t rsa -b 4096 -C "your_email@tum.de"
# !chmod 700 /root/.ssh
# !zip -r /content/key.zip /root/.ssh/id_rsa /root/.ssh/id_rsa.pub

# %% [markdown]
# ### Second step: Download key.zip manually

# %%
from google.colab import files
files.download('/content/key.zip')

# %% [markdown]
# ### Third step:
# 1. Go to gitlab.lrz.de
# 2. Click Settings
# 3. Click SSH Keys
# 4. Paste the public key from id_rsa.pub
# 5. Click the Add key button.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
